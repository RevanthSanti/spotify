# %%
import pandas as pd

# %%
# I have copied my personnel spotify library which contains 400 songs and imported it into csv file
data=pd.read_csv('my_liked_songs.csv')

# %%
data
# Out:
#                    Track ID  \
# 0    1MlM9FuR9WEfxC0mQcKjHK
# 1    2JzZzZUQj3Qff7wapcbKjc
# 2    7o3gnrSdBN1yJeyDd3ysWX
# 3    4ZdFMKqprNtEqdqdhu7gU0
# 4    3qrTll9OQ9wcejTxPFY0qg
# ..                      ...
# 400  7lGKEWMXVWWTt3X71Bv44I
# 401  0XDjtRaCmupZbkvvmtFIBB
# 402  6Qn5zhYkTa37e91HC1D7lb
# 403  2FY7b99s15jUprqC0M5NCT
# 404  5En1aTdTqSuVHD7mTWjQnz
#
#                                             Track Name  \
# 0                                Devudu Karunisthadani
# 1                   See You Again (feat. Charlie Puth)
# 2                                   Fear Song [TELUGU]
# 3    What Have They Done To Us (from the series Arc...
# 4    The Line (from the series Arcane League of Leg...
# ..                                                 ...
# 400                                           Unsteady
# 401                                       Start A Riot
# 402                                  Whatever It Takes
# 403                                            Natural
# ...

# %%
print('Shape of Data:',data.shape)
# Out:
# Shape of Data: (405, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track ID          405 non-null    object
#  1   Track Name        400 non-null    object
#  2   Album Name        400 non-null    object
#  3   Artist Name(s)    400 non-null    object
#  4   Release Date      405 non-null    object
#  5   Duration (ms)     405 non-null    int64
#  6   Popularity        405 non-null    int64
#  7   Added By          405 non-null    object
#  8   Added At          405 non-null    object
#  9   Genres            263 non-null    object
#  10  Record Label      400 non-null    object
#  11  Danceability      405 non-null    float64
#  12  Energy            405 non-null    float64
#  13  Key               405 non-null    int64
#  14  Loudness          405 non-null    float64
#  15  Mode              405 non-null    int64
# ...

# %%
data.describe()
# Out:
#        Duration (ms)  Popularity  Danceability      Energy         Key  \
# count     405.000000  405.000000    405.000000  405.000000  405.000000
# mean   228915.666667   42.135802      0.595533    0.561319    5.397531
# std     73536.336224   25.105891      0.153304    0.213458    3.500706
# min         0.000000    0.000000      0.149000    0.000934    0.000000
# 25%    189386.000000   24.000000      0.489000    0.403000    2.000000
# 50%    226386.000000   45.000000      0.601000    0.559000    6.000000
# 75%    273196.000000   63.000000      0.709000    0.718000    8.000000
# max    425506.000000   87.000000      0.956000    0.981000   11.000000
#
#          Loudness        Mode  Speechiness  Acousticness  Instrumentalness  \
# count  405.000000  405.000000   405.000000    405.000000        405.000000
# mean    -8.331225    0.558025     0.071367      0.396267          0.034086
# std      3.283001    0.497236     0.076236      0.301068          0.126346
# ...
